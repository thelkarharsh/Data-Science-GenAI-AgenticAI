# %% [markdown]
# # 28.Write a program that accepts a number and print whether it is a multiple of 10.

# %%
num= int(input("enter a number:"))
if num%10==0:
   print("multiple of 10:")
else:
   print("note multiple of 10")
# Out:
# enter a number: 80
# multiple of 10:

# %% [markdown]
# # 29.How would you check if a string a entered by the user contains only alphabets usging input()?

# %%
a1=input("enter a string:")
if a1.isalpha():
   print("only alphabets")
else:
   print("non-alphabet")
# Out:
# enter a string: jsdducbcbcd
# only alphabets

# %%
a1=input("enter a string:")
if a1.isalpha():
   print("only alphabets")
else:
   print("non-alphabet")
# Out:
# enter a string: 1223xdhdyd
# non-alphabet

# %% [markdown]
# # 30.Write a program to count the number of words in a sentence entered by the usre.

# %%
t=input("enter a sentence:")
print("number of word:",len(t.split()))
# Out:
# enter a sentence: Silence the kay to happiness
# number of word: 5

# %% [markdown]
# # 31.how do you aceepet a date input from the user in python?

# %%
from datetime import datetime
date_str=input("Enter a date (YEAR-MONTH-DATE)")
date=datetime.strptime(date_str,"%Y-%m-%d")
print("entered date:", date)
# Out:
# Enter a date (YEAR-MONTH-DATE) 2004-10-08
# entered date: 2004-10-08 00:00:00

# %% [markdown]
# # 32.Write a program that check if the entered number is divisible by both 3 and 5.

# %%
num=int(input("enter a number:"))
if num %3==0 and num % 5==0:
   print("divisible by both 3 and 5")
else:
   print("not divisible by both 3 and 5")
# Out:
# enter a number: 15
# divisible by both 3 and 5

# %% [markdown]
# num=int(input("enter a number:"))
# if num %3==0 and num % 5==0:
#    print("divisible by both 3 and 5")
# else:
#    print("not divisible by both 3 and 5")

# %% [markdown]
# # 33.Write a program to swap the value of two variable using input().

# %%
a= input("enter frist variable:")
b= input("enter second variable:")
a,b=b,a
print(f"swappend value:a={a},b={b}")
# Out:
# enter frist variable: 12
# enter second variable: 15
# swappend value:a=15,b=12

# %% [markdown]
# # 34.Write a program take user input and print it without space between words.

# %%
input1=input("enter a string:")
print(input1.replace(" ",""))
# Out:
# enter a string: qwerty
# qwerty

# %% [markdown]
# # 35.How do you validate if an entered input is availd email address?

# %%
import re 
email=input("engter email:") 
if re.match(r"[^@]+@[^@]+\.[^@]+",email):
    print("vaild email") 
else: 
 print("invalid email:")
# Out:
# engter email: harsh@gmail.com
# vaild email

# %%
import re 
email=input("engter email:") 
if re.match(r"[^@]+@[^@]+\.[^@]+",email):
    print("vaild email") 
else: 
 print("invalid email:")
# Out:
# engter email: harsh
# invalid email:

# %% [markdown]
# # 36.write a progaram that accepts a number and print its cube.

# %%
num=int(input("enter a number:")) 
print("cube:",num**3)
# Out:
# enter a number: 8
# cube: 512

# %% [markdown]
# # 37.How would you accepet and store multiple names from the user?

# %%
name=input("enter names separated by commas:").split(',') 
print("Name:",name)
# Out:
# enter names separated by commas: Harsh
# Name: ['Harsh']

# %% [markdown]
# # 38.How would you extaract numbers from a string enterd by the user?

# %%
import re 
t=input("enter a sting:") 
numbers=re.findall(r'\d+',t) 
print("extracted numbers:",numbers)
# Out:
# enter a sting: 12345qwrty
# extracted numbers: ['12345']

# %% [markdown]
# # 39.How do you find the maximum number from a list of integers enterd by the user?

# %%
num=list(map(int,input("enter number separated by space:").split()))
print("maximum num:",max(num))
# Out:
# enter number separated by space: 12 13
# maximum num: 13

# %% [markdown]
# # 40.How would you prompt the user for input until they enter a vaild number?

# %%
while True: 
 try: 
     num=int(input("enter a vaild number."))
     break 
 except ValueError as e: 
     print("invalid input ")
# Out:
# enter a vaild number. 123erty
# invalid input
# enter a vaild number. 1234

# %% [markdown]
# # 41.Write a program to check if the enterd string has digits

# %%
string = input("enter a string:") 
for char in string: 
 if char.isdigit() == True:  print("contains digits")
 break 
else: 
 print("no digits")
# Out:
# enter a string: 1234ertyujnbvc
# contains digits

# %% [markdown]
# # 42.Write a program to check if the entered string has only whitespace characters.

# %%
num= input("a string:") 
if num.isspace(): 
 print("only whitespace") 
else: 
 print("non whitespace")
# Out:
# a string: zxcvbn
# non whitespace

# %%
num= input("a string:") 
if num.isspace(): 
 print("only whitespace") 
else: 
 print("non whitespace")
# Out:
# a string: q w e r t y
# non whitespace

# %% [markdown]
# # 43.Write a program to find the sum of all digit in a string enterd by the user.

# %%
text=input("enter a string:") 
digit_sum=sum(int(digit) for digit in text if 
digit.isdigit())
print("sum of digit:",digit_sum)
# Out:
# enter a string: 0987ytrewq
# sum of digit: 24

# %% [markdown]
# # 44.Write a program that accepet a number and prints its absolute value.

# %%
num=int(input("enter a number:"))
print("Absolute vale:",abs(num))
# Out:
# enter a number: 123
# Absolute vale: 123

# %% [markdown]
# # 45.How would you check if a string entered by the user contains any uppercase letters?

# %%
user_string = input("Enter a string: ") 
if any(ch.isupper() for ch in user_string): 
 print("The string contains uppercase letters.") 
else: 
 print("The string does not contain uppercase letters.")
# Out:
# Enter a string:  harsh
# The string does not contain uppercase letters.

# %%
user_string = input("Enter a string: ") 
if any(ch.isupper() for ch in user_string): 
 print("The string contains uppercase letters.") 
else: 
 print("The string does not contain uppercase letters.")
# Out:
# Enter a string:  HARSH
# The string contains uppercase letters.

# %% [markdown]
# # 46. Write a program that converts Celsius to Fahrenheit.

# %%
celsius = float(input("Enter temperature in Celsius: ")) 
fahrenheit = (celsius * 9/5) + 32 
print(f"{celsius}°C is equal to {fahrenheit}°F")
# Out:
# Enter temperature in Celsius:  12
# 12.0°C is equal to 53.6°F

# %% [markdown]
# # 47. Write a program to find the average of a list of numbers entered by the user.

# %%
numbers_input = input("Enter numbers separated by spaces: ") 
numbers = [float(num) for num in numbers_input.split()] 
average = sum(numbers) / len(numbers) 
print("Average:", average)
# Out:
# Enter numbers separated by spaces:  15 08
# Average: 11.5

# %% [markdown]
# # 48. Write a program to count the number of consonants in a string entered by the user.

# %%
user_string = input("Enter a string: ") 
vowels = "aeiouAEIOU" 
consonant_count = 0 
for ch in user_string: 
 if ch.isalpha() and ch not in vowels:  consonant_count += 1 
print("Number of consonants:", consonant_count)
# Out:
# Enter a string:  harshthelkar
# Number of consonants: 9

# %% [markdown]
# # 49. How do you check if a string entered by the user contains any punctuation?

# %%
import string 
user_string = input("Enter a string: ") 
if any(ch in string.punctuation for ch in user_string):  
    print("The string contains punctuation.") 
else: 
    print("The string does not contain punctuation.")
# Out:
# Enter a string:  asdfghj
# The string does not contain punctuation.

# %%
import string 
user_string = input("Enter a string: ") 
if any(ch in string.punctuation for ch in user_string):  
    print("The string contains punctuation.") 
else: 
    print("The string does not contain punctuation.")
# Out:
# Enter a string:  asdf@#
# The string contains punctuation.

# %% [markdown]
# # 50. Write a program that accepts a sentence and prints the longest word.

# %%
sentence = input("Enter a sentence: ") 
words = sentence.split() 
longest_word = max(words, key=len) 
print("Longest word:", longest_word)
# Out:
# Enter a sentence:  Harsh Vaibhav Shrijit
# Longest word: Vaibhav
