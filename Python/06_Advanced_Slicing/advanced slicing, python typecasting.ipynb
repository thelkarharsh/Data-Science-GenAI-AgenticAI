# %% [markdown]
# #### WELCOME TO FSDS_GENAI_AGENTIC AI PROGRAMME_ PRKASH SENAPATI_NARESHIT

# %% [markdown]
# # 1- python variable

# %%
v = 5
v
# Out:
# 5

# %%
5 = v
# Out:
#   Cell In[8], line 1
#     5 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
1nit = 27
# Out:
#   Cell In[9], line 1
#     1nit = 27
#     ^
# SyntaxError: invalid decimal literal

# %%
nit1 = 27
nit1
# Out:
# 27

# %%
v1 = 25
a1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 v1 = 25
# ----> 2 a1
#
# NameError: name 'a1' is not defined

# %%
v1 = 25
v1
# Out:
# 25

# %%
v
nit1
v1
# Out:
# 25

# %%
print(v)
print(nit1)
print(v1)
# Out:
# 5
# 27
# 25

# %%
nit2 = 45
NIT2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 nit2 = 45
# ----> 2 NIT2
#
# NameError: name 'NIT2' is not defined

# %%
nit2 = 45
nit2
# Out:
# 45

# %%
45= nit2
# Out:
#   Cell In[25], line 1
#     45= nit2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
Nit3 = 50
Nit3
# Out:
# 50

# %%
nit@ = 56
nit@
# Out:
#   Cell In[29], line 1
#     nit@ = 56
#          ^
# SyntaxError: invalid syntax

# %%
nit% = 6
# Out:
#   Cell In[30], line 1
#     nit% = 6
#          ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
def = 56
# Out:
#   Cell In[35], line 1
#     def = 56
#         ^
# SyntaxError: invalid syntax

# %%
Def = 56
Def
# Out:
# 56

# %% [raw]
# - varaible are case sensitive
# - variaare doesnot start with digit or number but ends with number
# - special character are not allowed except _
# - keywords or reserve words are not declare as variable

# %% [markdown]
# # 6th

# %%
i = 5 
i
# Out:
# 5

# %%
type()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 type()
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(i)
# Out:
# int

# %%
i
# Out:
# 5

# %%
id(i)
# Out:
# 140713444877352

# %%
age = 24 
age
# Out:
# 24

# %%
print(type(age))
print(id(age))
# Out:
# <class 'int'>
# 140713444877960

# %% [markdown]
# # float

# %%
f = 110.23
f
# Out:
# 110.23

# %%
type(f)
# Out:
# float

# %%
id(f)
# Out:
# 3086101801872

# %%
print(i)
print(f)
# Out:
# 5
# 110.23

# %% [markdown]
# # bool

# %%
b = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 b = true
#
# NameError: name 'true' is not defined

# %%
b = True
b
# Out:
# True

# %%
type(b)
# Out:
# bool

# %%
b1 = False
b1
# Out:
# False

# %%
type(b1)
# Out:
# bool

# %%
p = 20
q = 20

# %%
p, q = 20, 20

# %%
print(id(p))
print(id(q))
# Out:
# 140713444877832
# 140713444877832

# %%
print(p)
print(q)
# Out:
# 20
# 20

# %%
p = p + 10
p
# Out:
# 30

# %%
print(p)
print(q)
# Out:
# 30
# 20

# %%
print(id(p))
print(id(q))
# Out:
# 140713444878152
# 140713444877832

# %%
print(b)
print(b1)
# Out:
# True
# False

# %%
b
# Out:
# True

# %%
b1
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
True + False
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
False * True
# Out:
# 0

# %%
False / True
# Out:
# 0.0

# %%
False // True
# Out:
# 0

# %% [markdown]
# # complex

# %%
c = 10 + 20j 
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
c1 = 20+30J
c1
# Out:
# (20+30j)

# %%
print(c)
print(c1)
# Out:
# (10+20j)
# (20+30j)

# %%
c
# Out:
# (10+20j)

# %%
c.real
# Out:
# 10.0

# %%
c.imag
# Out:
# 20.0

# %%
print(c)
print(c1)
# Out:
# (10+20j)
# (20+30j)

# %%
c + c1
# Out:
# (30+50j)

# %% [markdown]
# # 7th -- String

# %%
s = welcome team
# Out:
#   Cell In[87], line 1
#     s = welcome team
#                 ^
# SyntaxError: invalid syntax

# %%
s = 'welcome team' # single quotes 
s
# Out:
# 'welcome team'

# %%
s1 = "welcome team" # double quotes 
s1
# Out:
# 'welcome team'

# %%
s2 = ''' welcome team'''
s2
# Out:
# ' welcome team'

# %%
s3 = 'welcome to nareshit
       under prakash senapati guidance
       4pm batch'
s3
# Out:
#   Cell In[94], line 1
#     s3 = 'welcome to nareshit
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s4 = "welcome to nareshit
       under prakash senapati guidance
       4pm batch"
s4
# Out:
#   Cell In[95], line 1
#     s4 = "welcome to nareshit
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s4 = '''welcome to nareshit
       under prakash senapati guidance
       4pm batch'''
s4
# Out:
# 'welcome to nareshit\n       under prakash senapati guidance\n       4pm batch'

# %% [markdown]
# # string indexes

# %%
si = 'welcome'
si
# Out:
# 'welcome'

# %%
si[0]
# Out:
# 'w'

# %%
si[4]
# Out:
# 'o'

# %%
si
# Out:
# 'welcome'

# %%
si[6]
# Out:
# 'e'

# %%
si[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 si[7]
#
# IndexError: string index out of range

# %%
si
# Out:
# 'welcome'

# %%
si[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 si[10]
#
# IndexError: string index out of range

# %%
si
# Out:
# 'welcome'

# %%
si[-1]
# Out:
# 'e'

# %%
si[-2]
# Out:
# 'm'

# %%
si[-7]
# Out:
# 'w'

# %%
si[-1000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 si[-1000]
#
# IndexError: string index out of range

# %%
# forward index & backward index & Indexing error

# %%
si
# Out:
# 'welcome'

# %%
si[:]
# Out:
# 'welcome'

# %%
si
# Out:
# 'welcome'

# %%
si[1:4]
# Out:
# 'elc'

# %%
si
# Out:
# 'welcome'

# %%
si[0:6]
# Out:
# 'welcom'

# %%
si
# Out:
# 'welcome'

# %%
si[3:7]
# Out:
# 'come'

# %%
si
# Out:
# 'welcome'

# %%
si[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 si[10]
#
# IndexError: string index out of range

# %%
si[3:10]
# Out:
# 'come'

# %%
si[3:100]
# Out:
# 'come'

# %%
si
# Out:
# 'welcome'

# %%
si[3:5]
# Out:
# 'co'

# %%
si
# Out:
# 'welcome'

# %%
si[1:]
# Out:
# 'elcome'

# %%
si[:]
# Out:
# 'welcome'

# %%
si[3:]
# Out:
# 'come'

# %%
si[:]
# Out:
# 'welcome'

# %%
si[:4]
# Out:
# 'welc'

# %%
si
# Out:
# 'welcome'

# %%
si[:6]
# Out:
# 'welcom'

# %%
si
# Out:
# 'welcome'

# %%
si[0:7:2] #step slicing
# Out:
# 'wloe'

# %%
si
# Out:
# 'welcome'

# %%
si[0:7:4]
# Out:
# 'wo'

# %%
si
# Out:
# 'welcome'

# %%
si[-5 : -1]
# Out:
# 'lcom'

# %%
si
# Out:
# 'welcome'

# %%
si[::2]
# Out:
# 'wloe'

# %%
si[::3]
# Out:
# 'wce'

# %%
si
# Out:
# 'welcome'

# %%
si[::-1]
# Out:
# 'emoclew'

# %%
si
# Out:
# 'welcome'

# %%
si[::-2]
# Out:
# 'eolw'

# %% [markdown]
# ##### string indexing, slicing, forward slicing, backward slicing, step slicing, advance slicing

# %% [markdown]
# # python type casting

# %%
110.34
# Out:
# 110.34

# %%
int(110.34) # we can convert float to int
# Out:
# 110

# %%
int(True) # boolean to int possible
# Out:
# 1

# %%
int(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 int(1+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[161], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# # in type casting while typecast from all other datatype to int possible except complex & text string

# %% [markdown]
# # other datatype to float

# %%
float(110)
# Out:
# 110.0

# %%
float(True)
# Out:
# 1.0

# %%
float(false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 float(false)
#
# NameError: name 'false' is not defined

# %%
float(False)
# Out:
# 0.0

# %%
float(1+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 float(1+2j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')  # number string
# Out:
# 10.0

# %%
float('ten') #text string
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 float('ten') #text string
#
# ValueError: could not convert string to float: 'ten'

# %% [markdown]
# # other datatype to boolean

# %%
bool(2)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool(2.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool('10')
# Out:
# True

# %%
bool('ten')
# Out:
# True

# %%
bool( )
# Out:
# False

# %%
bool(-2)
# Out:
# True

# %% [markdown]
# # all other datatype to complex

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex(3, 4)
# Out:
# (3+4j)

# %%
complex(3,4,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 complex(3,4, 5)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3, 4.5)
# Out:
# (2.3+4.5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[185], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex('10', '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 complex('10', '20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex(10, '20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 complex(10, '20')
#
# TypeError: complex() second arg can't be a string

# %%
str(10)
# Out:
# '10'

# %%
str(10.4)
# Out:
# '10.4'

# %%
str(True)
# Out:
# 'True'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %% [markdown]
# # python type casting we are completed
