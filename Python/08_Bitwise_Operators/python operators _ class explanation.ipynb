# %%
2 + 3
10 - 6
10 * 5
# Out:
# 50

# %%
print(2+3)
print(10-6)
print(10*5)
# Out:
# 5
# 4
# 50

# %%
a = 10
b = 20

print(a)
print(b)
# Out:
# 10
# 20

# %%
print(a, b)
# Out:
# 10 20

# %%
c = 30
print(a)
print(b)
print(c)

print(a, b, c)
# Out:
# 10
# 20
# 30
# 10 20 30

# %%
print(10) 
print(10,20) 
print('python') 
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
print()

# %%
num1=20
num2=30
add=num1+num2
print(add)
# Out:
# 50

# %%
num1=20
num2=30
add=num1+num2
print('The addition of',num1,'and',num2,'is=',add)
# Out:
# The addition of 20 and 30 is= 50

# %%
num1=20
num2=30
num3=50
add=num1+num2+num3
print('The addition of',num1,'and',num2,'and',num3,'is=',add)
# Out:
# The addition of 20 and 30 myname 50 is= 100

# %%
name='Python'
age=20
city='hyderbad city'

print('My name is',name,'and i am',age,'years old form',city)
# Out:
# My name is Python and i am 20 years old form hyderbad city

# %% [markdown]
# # print() with format method

# %%
num1=20
num2=30

add=num1+num2

print('The addition of {} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is= 50

# %%
num1=20
num2=30
num3=40
num4=50

add=num1+num2+num3+num4 

print('The addition of {} and {} and {} and {} is= {}'.format(num1,num2,num3,num4,add))
# Out:
# The addition of 20 and 30 and 40 and 50 is= 140

# %%
num1 = 20
num2 = 30
add=num1+num2
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 20 and 30 is= 50

# %%
print('hello') # 1st statement
print('good evening') # 2nd statement)
# Out:
# hello
# good evening

# %%
print('hello', end=' ') # 1st statement
print('world good day') # 2nd statement
# Out:
# hello world good day

# %%
print('hello', end=' ### ') # 1st statement
print('world good day') # 2nd statement
# Out:
# hello ### world good day

# %%
print('hello','hai','how are you',sep='--->')
# Out:
# hello--->hai--->how are you

# %%
print('hello','hai','how are you',sep='*****')
# Out:
# hello*****hai*****how are you

# %% [markdown]
# # print() we are completed

# %%
x = 2

# %%
x += 2

# %%
x
# Out:
# 4

# %%
x += 2
x
# Out:
# 6

# %%
x *= 2
x
# Out:
# 12

# %%
x *= 2
x
# Out:
# 24

# %%
x -= 2
x
# Out:
# 22

# %%
x //= 2

# %%
x
# Out:
# 11

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
print(a)
print(b)
# Out:
# 5
# 6

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
b = 5

# %%
a == b
# Out:
# True

# %%
a != b
# Out:
# False

# %%
a = 5
b = 4

# %%
a < 8 and b < 5
# Out:
# True

# %%
a < 8 and b > 5
# Out:
# False

# %%
a < 8 or b < 2
# Out:
# True

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True

# %%
y = True 
y
# Out:
# True

# %%
not y
# Out:
# False

# %% [markdown]
# # 12th --- Number System

# %%
25
# Out:
# 25

# %%
bin(25) # we converte number to binary number system
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %%
oct(25) # number to octal number system
# Out:
# '0o31'

# %%
int(0o31) # octal to number
# Out:
# 25

# %%
hex(16)
# Out:
# '0x10'

# %%
int(0x10)
# Out:
# 16

# %%
int(0x9)
# Out:
# 9

# %%
hex(25)
# Out:
# '0x19'

# %%
int(0x19)
# Out:
# 25

# %% [markdown]
# # complement

# %%
~12
# Out:
# -13

# %%
~35
# Out:
# -36

# %%
~18
# Out:
# -19

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
12 ^ 13
# Out:
# 1

# %%
12 << 2
# Out:
# 48

# %%
12 << 1
# Out:
# 24

# %%
12>>1
# Out:
# 6

# %%
12>>2
# Out:
# 3

# %% [markdown]
# # bitwise operator we are completed

# %%
a = 5
b = 6

# %%
a = b
b = a

# %%
print(a)
print(b)
# Out:
# 6
# 6

# %%
a1, b1 = 7, 8

print(a1)
print(b1)
# Out:
# 7
# 8

# %%
temp = a1 
a1 = b1
b1 = temp

# %%
print(a1)
print(b1)
# Out:
# 8
# 7

# %%
a2 = 5
b2 = 6

# %%
a2 = a2 + b2 # 5+6 = 11 
b2 = a2 - b2 # 11-6 = 5
a2 = a2 - b2 # 11-5 = 6

# %%
print(a2)
print(b2)
# Out:
# 6
# 5

# %%
a3, b3 = 2, 4

# %%
a3, b3 = b3, a3

# %%
print(a3)
print(b3)
# Out:
# 4
# 2

# %%
# basic python we are completed today
