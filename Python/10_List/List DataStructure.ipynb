# %%
# List Datastructure

# %%
l = []
l
# Out:
# []

# %%
type(1)
# Out:
# int

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(20,30,40)
l
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l.append(20,30,40)
#       2 l
#
# TypeError: list.append() takes exactly one argument (3 given)

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 5

# %%
l
# Out:
# [10, 20, 30, 40, 50]

# %%
l.append(10)
l
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
l1 =[10,3.5,True,1+2j,'harsh']
l1
# Out:
# [10, 3.5, True, (1+2j), 'harsh']

# %%
l1.append([1,2,3]) # nested list
l1
# Out:
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10]
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
l3 = l.copy()
l3
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10, 10]
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10, 10]

# %%
l == l3
# Out:
# True

# %%
len(l) == len(l3)
# Out:
# True

# %%
id(1)  ==  id(l3)
# Out:
# False

# %%
id(1) != id(l3)
# Out:
# True

# %%
print(id(1))
print(id(l3))
# Out:
# 140725948441720
# 1886171376512

# %%
print(l)
print(l1)
print(l3)
# Out:
# [10, 20, 30, 40, 50, 10, 10]
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]
# [10, 20, 30, 40, 50, 10, 10]

# %%
l.count(10)
# Out:
# 3

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
l.count(10)
# Out:
# 3

# %%
l
# Out:
# [10, 20, 30, 40, 50, 10, 10]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10]
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
l.extend(l1)
l
# Out:
# [10, 20, 30, 40, 50, 10, 10, 10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
print(len(l))
print(len(l1))
# Out:
# 13
# 6

# %%
a1 = [1,2,3]
b1 = [4,5,6]

# %%
a1.extend(b1)
a1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
print(a1)
print(b1)
# Out:
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50, 10, 10, 10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
l.index(20)
# Out:
# 1

# %%
l1.index(1+2j)
# Out:
# 3

# %%
l1.index('harsh')
# Out:
# 4

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
l1[5]
# Out:
# [1, 2, 3]

# %%
l1[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 l1[6]
#
# IndexError: list index out of range

# %%
l1[4]
# Out:
# 'harsh'

# %%
l1[:3]
# Out:
# [10, 3.5, True]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
l1[3:]
# Out:
# [(1+2j), 'harsh', [1, 2, 3]]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
l1[0:5:2]
# Out:
# [10, True, 'harsh']

# %%
l1[-3]
# Out:
# (1+2j)

# %%
l1[-3]
# Out:
# (1+2j)

# %%
l1[::-1]
# Out:
# [[1, 2, 3], 'harsh', (1+2j), True, 3.5, 10]

# %%
l1[::-2]
# Out:
# [[1, 2, 3], (1+2j), 3.5]

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
l1[4]
# Out:
# 'harsh'

# %%
print(l1[4][0])
print(l1[4][1])
print(l1[4][2])
print(l1[4][3])
print(l1[4][4])
# Out:
# h
# a
# r
# s
# h

# %%
l1
# Out:
# [10, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
l1[0]
# Out:
# 10

# %%
l1[0] = 100
l1
# Out:
# [100, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]

# %%
l1
# Out:
# [100, 3.5, True, (1+2j), 'harsh', [1, 2, 3]]
