# %% [markdown]
# # DATA STRUCTURE

# %% [markdown]
# #List
#
# 1. List is defined using square brackets [].
# 2. append() adds a value to the end of the list.
# 3. Duplicate values are allowed in a list.
# 4. len(list_name) returns the number of elements in the list.
# 5. A list can hold multiple data types.
# 6. The id() function returns the unique identity (ID) of the list. Example: id(l)
# 7. clear() removes all elements from the list.
# 8. copy() creates a copy of the list. Example: l2 = l.copy()
# 9. del() delets the lsit
# 10. count() function number of occurances of value in list
# 11. index() Adds a value at a specific position.
# 12. extend() Adds multiple values from another list.
# 13. remove() Removes the first matching value.
# 14. pop()  Removes and returns an element.
# 15. pop(index) Removes an element from a specific position
# 16. index()  Returns the position of a value.
# 17. Sliceing is alowed in list

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.clear()
l.append(10)#only append one at a time 
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(10)
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l.append(60)
l
# Out:
# [10, 10, 20, 30, 40, 50, 60]

# %%
len(l)
# Out:
# 7

# %%
l.append("adarash")
l.append(3.20)
l
# Out:
# [10, 10, 20, 30, 40, 50, 60, 'adarash', 3.2]

# %%
l=[[1,2,3,4,5,6],10, 10, 20, 30, 40, 50, 60,'adarash', 3.2]
l
# Out:
# [[1, 2, 3, 4, 5, 6], 10, 10, 20, 30, 40, 50, 60, 'adarash', 3.2]

# %%
l2=l.copy()
l2
# Out:
# [[1, 2, 3, 4, 5, 6], 10, 10, 20, 30, 40, 50, 60, 'adarash', 3.2]

# %%
print('list1',l)
print('list2',l2)
# Out:
# list1 [[1, 2, 3, 4, 5, 6], 10, 10, 20, 30, 40, 50, 60, 'adarash', 3.2]
# list2 [[1, 2, 3, 4, 5, 6], 10, 10, 20, 30, 40, 50, 60, 'adarash', 3.2]

# %%
l==l2
# Out:
# True

# %%
id(l)
# Out:
# 1856664308480

# %%
id(l2)
# Out:
# 1856664272576

# %%
id(l)==id(l2)
# Out:
# False

# %%
id(l)!=id(l2)
# Out:
# True

# %%
del(l2)
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 del(l2)
#       2 l2
#
# NameError: name 'l2' is not defined

# %%
l.count(10)
# Out:
# 1

# %%
l2=[1,2,3,4,5,6]

# %%
l.extend(l2)
l
# Out:
# [40, 'Python', 'Python', 30, 20, 15, 4, 5, 1, 2, 3, 4, 5, 6]

# %%
l.remove(1)
l
# Out:
# [40, 'Python', 'Python', 4, 5, 2, 3, 4]

# %%
l.pop()
# Out:
# 5

# %%
l.pop(2)
# Out:
# 15

# %%
print(l)
l.index(3)
# Out:
# [40, 'Python', 'Python', 4, 5, 2, 3, 4]
# 6

# %%
print(l)
l.index('Python')
# Out:
# [40, 'Python', 'Python', 4, 5, 2, 3, 4]
# 1

# %%
l
# Out:
# [40, 'Python', 'Python', 4, 5, 2, 3, 4]

# %%
l[:]
# Out:
# [40, 'Python', 'Python', 4, 5, 2, 3, 4]

# %%
l[5]
# Out:
# 2

# %%
l[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 l[9]
#
# IndexError: list index out of range

# %%
print(l)
l[:3]
# Out:
# [40, 'Python', 'Python', 4, 5, 2, 3, 4]
# [40, 'Python', 'Python']

# %%
print(l)
l[2:5]
# Out:
# [40, 'Python', 'Python', 4, 5, 2, 3, 4]
# ['Python', 4, 5]

# %%
l[:-3]
# Out:
# [40, 'Python', 'Python', 4, 5]

# %%
l[::-5]
# Out:
# [4, 'Python']

# %%
print(l[1][0])
print(l[1][1])
print(l[1][2])
print(l[1][3])
print(l[1][4])
print(l[1][5])
# Out:
# P
# y
# t
# h
# o
# n

# %%
l2= [0]
l2
# Out:
# [0]

# %%
l2.insert(2,5)
l2
# Out:
# [0, 5, 5]

# %%
l2.insert(1,[1,2,3])
l2
# Out:
# [0, [1, 2, 3], [1, 2, 3], 5, 5]

# %%
l2.pop()
# Out:
# 5

# %%
l2
# Out:
# [0, [1, 2, 3], [1, 2, 3], 5]

# %%
l2.pop(-2)
# Out:
# [1, 2, 3]

# %%
l2.reverse()
l2
# Out:
# [0, [1, 2, 3], 5]

# %%
l2[::-1]
# Out:
# [5, [1, 2, 3], 0]

# %%
l2.sort[]

# %%
l3=[12,10,56,3,2,78,15]
l3
# Out:
# [12, 10, 56, 3, 2, 78, 15]

# %%
l3.sort()
l3
# Out:
# [2, 3, 10, 12, 15, 56, 78]

# %%
l3.sort(reverse=False)
l3
# Out:
# [2, 3, 10, 12, 15, 56, 78]

# %%
l3.sort(reverse=True)
l3
# Out:
# [78, 56, 15, 12, 10, 3, 2]

# %% [markdown]
# TUPLE

# %%
t= ()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t= (1,2,3,4,5,6)
t
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
t1= (1,2,"adar1.sh",)
t1
# Out:
# (1, 2, 'adarsh')

# %%
t1.index(4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 t1.index(4)
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# SET={}
# dupilicate is not allowed i set
# it prints in ordered if datatype is same
# indexing and slicing is not allowed in set
# s

# %%
s= {1,2,3,3}
s
# Out:
# {1, 2, 3}

# %%
s2= {1,2,3,4,(1+5j),"0adarsh"}
s2
# Out:
# {(1+5j), '0adarsh', 1, 2, 3, 4}

# %%
s2.add(9)
s2
# Out:
# {'0adarsh', 1, 3, 4, 9}

# %%
s3=s2.copy()
s3
# Out:
# {(1+5j), '0adarsh', 1, 2, 3, 4, 9}

# %%
s3.discard(1)
s3
# Out:
# {(1+5j), '0adarsh', 2, 3, 4, 9}

# %%
s3.remove(2)
s2
# Out:
# {'0adarsh', 1, 3, 4, 9}
