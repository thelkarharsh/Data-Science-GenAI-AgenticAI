# %% [markdown]
# ##Dictionary

# %%
d ={1:"one",2:"two",3:"three"}
d
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
type(d)
# Out:
# dict

# %%
d.pop(2)
d
# Out:
# {1: 'one', 3: 'three'}

# %% [markdown]
# # 2 in d

# %%
1 in d
# Out:
# True
