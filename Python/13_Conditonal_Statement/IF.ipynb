# %% [markdown]
# conditional Statement

# %%
# write python script  to check wheter the number even or odd
x = 4
print(x)
r = x % 2
if r == 0:
   print("even number")
# Out:
# 4
# even number

# %%
# write python script  to check wheter the number even or odd
x = 5
print(x)
r = x % 2
if r == 0:
   print("even number")
if r != 0:
   print("odd number")
# Out:
# 5
# odd number

# %%
# write python script  to check wheter the number even or odd
x = 5
print(x)
r = x % 2
if r == 0:
   print("even number")
else:
    print("odd number")
# Out:
# 5
# odd number
