# %% [markdown]
# # Range

# %%
range(5)
# Out:
# range(0, 5)

# %%
list(range(0,5))
# Out:
# [0, 1, 2, 3, 4]

# %%
list(range(10,20,30))
# Out:
# [10]

# %% [markdown]
# # conditional Statement

# %%
if
else
if elif else
nested if
